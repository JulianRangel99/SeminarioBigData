# %% [markdown]
# <a href="https://colab.research.google.com/github/JulianRangel99/SeminarioBigData/blob/main/Laboratorio_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *   NICOLAS SEPULVEDA - 69614
# *   JULIAN RANGEL - 89721

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib. pyplot as pl
import seaborn as sns
data = {'year': [
2010, 2011, 2012,
2010, 2011, 2012,
2010, 2011, 2012
] ,
'team': [
'FCBarcelona', 'FCBarcelona',
'FCBarcelona', 'RMadrid',
'RMadrid', 'RMadrid',
'ValenciaCF', 'ValenciaCF',
'ValenciaCF'
] ,
'wins': [30, 28, 32, 29, 32, 26, 21, 17, 19],
'draws': [6, 7, 4, 5, 4, 7, 8, 10, 8],
'losses': [2, 3, 2, 4, 2, 5, 9, 11, 11]
}
football = pd.DataFrame(data , columns = [ 'year', 'team', 'wins', 'draws', 'losses'])
football.head()
# Out:
#    year         team  wins  draws  losses
# 0  2010  FCBarcelona    30      6       2
# 1  2011  FCBarcelona    28      7       3
# 2  2012  FCBarcelona    32      4       2
# 3  2010      RMadrid    29      5       4
# 4  2011      RMadrid    32      4       2

# %%
edu = pd.read_csv ('/content/educ_figdp_1_Data.csv',na_values = ':',usecols = ["TIME","GEO","Value"])
edu
# Out:
#      TIME                            GEO  Value
# 0    2000  European Union (28 countries)    NaN
# 1    2001  European Union (28 countries)    NaN
# 2    2002  European Union (28 countries)   5.00
# 3    2003  European Union (28 countries)   5.03
# 4    2004  European Union (28 countries)   4.95
# ..    ...                            ...    ...
# 379  2007                        Finland   5.90
# 380  2008                        Finland   6.10
# 381  2009                        Finland   6.81
# 382  2010                        Finland   6.85
# 383  2011                        Finland   6.76
#
# [384 rows x 3 columns]

# %%
edu.head()
# Out:
#    TIME                            GEO  Value
# 0  2000  European Union (28 countries)    NaN
# 1  2001  European Union (28 countries)    NaN
# 2  2002  European Union (28 countries)   5.00
# 3  2003  European Union (28 countries)   5.03
# 4  2004  European Union (28 countries)   4.95

# %%
edu.tail()
# Out:
#      TIME      GEO  Value
# 379  2007  Finland   5.90
# 380  2008  Finland   6.10
# 381  2009  Finland   6.81
# 382  2010  Finland   6.85
# 383  2011  Finland   6.76

# %%
edu.describe()
# Out:
#               TIME       Value
# count   384.000000  361.000000
# mean   2005.500000    5.203989
# std       3.456556    1.021694
# min    2000.000000    2.880000
# 25%    2002.750000    4.620000
# 50%    2005.500000    5.060000
# 75%    2008.250000    5.660000
# max    2011.000000    8.810000

# %%
edu['Value']
# Out:
# 0       NaN
# 1       NaN
# 2      5.00
# 3      5.03
# 4      4.95
#        ...
# 379    5.90
# 380    6.10
# 381    6.81
# 382    6.85
# 383    6.76
# Name: Value, Length: 384, dtype: float64

# %%
edu[10:14]
# Out:
#     TIME                            GEO  Value
# 10  2010  European Union (28 countries)   5.41
# 11  2011  European Union (28 countries)   5.25
# 12  2000  European Union (27 countries)   4.91
# 13  2001  European Union (27 countries)   4.99

# %%
edu.loc[90:94,['TIME','GEO']]
# Out:
#     TIME      GEO
# 90  2006  Belgium
# 91  2007  Belgium
# 92  2008  Belgium
# 93  2009  Belgium
# 94  2010  Belgium

# %% [markdown]
# * se realiza el cambio de .ix por .loc de acuerdo al que el phyton se encuentra desactualizado

# %%
edu[edu['Value'] > 6.5].tail()
# Out:
#      TIME      GEO  Value
# 286  2010    Malta   6.74
# 287  2011    Malta   7.96
# 381  2009  Finland   6.81
# 382  2010  Finland   6.85
# 383  2011  Finland   6.76

# %%
edu[edu["Value"].isnull()].head()
# Out:
#     TIME                            GEO  Value
# 0   2000  European Union (28 countries)    NaN
# 1   2001  European Union (28 countries)    NaN
# 36  2000       Euro area (18 countries)    NaN
# 37  2001       Euro area (18 countries)    NaN
# 48  2000       Euro area (17 countries)    NaN

# %%
edu. max(axis = 0)
# Out:
# TIME      2011
# GEO      Spain
# Value     8.81
# dtype: object

# %%
print ("Pandas max function:", edu['Value']. max ())
print ("Python max function:", max(edu['Value']))
# Out:
# Pandas max function: 8.81
# Python max function: nan

# %%
s = edu["Value" ]/100

s.head()
# Out:
# 0       NaN
# 1       NaN
# 2    0.0500
# 3    0.0503
# 4    0.0495
# Name: Value, dtype: float64

# %%
s = edu["Value"]. apply (np.sqrt)

s.head()
# Out:
# 0         NaN
# 1         NaN
# 2    2.236068
# 3    2.242766
# 4    2.224860
# Name: Value, dtype: float64

# %%
s = edu["Value"]. apply ( lambda d: d**2)

s.head()
# Out:
# 0        NaN
# 1        NaN
# 2    25.0000
# 3    25.3009
# 4    24.5025
# Name: Value, dtype: float64

# %%
edu['ValueNorm'] = edu['Value']/edu['Value']. max ()

edu.tail()
# Out:
#      TIME      GEO  Value  ValueNorm
# 379  2007  Finland   5.90   0.669694
# 380  2008  Finland   6.10   0.692395
# 381  2009  Finland   6.81   0.772985
# 382  2010  Finland   6.85   0.777526
# 383  2011  Finland   6.76   0.767310

# %%
edu.drop('ValueNorm', axis = 1, inplace = True)

edu.head()
# Out:
#    TIME                            GEO  Value
# 0  2000  European Union (28 countries)    NaN
# 1  2001  European Union (28 countries)    NaN
# 2  2002  European Union (28 countries)   5.00
# 3  2003  European Union (28 countries)   5.03
# 4  2004  European Union (28 countries)   4.95

# %%
# Definir el DataFrame inicial
edu = pd.DataFrame(columns=['TIME', 'Value', 'GEO'])

# Crear un nuevo DataFrame con la fila que quieres agregar
new_row = edu.DataFrame({"TIME": [2000], "Value": [5.00], "GEO": ['a']})

# Concatenar ambos DataFrames
edu = pd.concat([edu, new_row], ignore_index=True)




# edu = pd.DataFrame(columns=['TIME', 'Value', 'GEO'])
# edu = edu.append({"TIME": 2000, "Value":5.00,"GEO": 'a'} , ignore_index = True)
edu.tail()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-e03ff7fbdee3> in <cell line: 5>()
#       3
#       4 # Crear un nuevo DataFrame con la fila que quieres agregar
# ----> 5 new_row = edu.DataFrame({"TIME": [2000], "Value": [5.00], "GEO": ['a']})
#       6
#       7 # Concatenar ambos DataFrames
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#    5990
#    5991     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'DataFrame'
